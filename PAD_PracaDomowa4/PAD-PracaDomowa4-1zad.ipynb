# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Zadanie_1.csv", sep=';')

df
# Out:
#       x1    x2    x3    x4    x5    x6    x7    x8    x9   x10   x11    x12  \
# 0   36.0  27.0  71.0   8.1  3.34  11.4  81.5  3243   8.8  42.6  11.7   21.0
# 1   35.0  23.0  72.0  11.1  3.14  11.0  78.8  4281   3.6  50.7  14.4    8.0
# 2   44.0  29.0  74.0  10.4  3.21   9.8  81.6  4260   0.8  39.4   NaN    6.0
# 3   47.0  45.0  79.0   6.5  3.41  11.1  77.5  3125  27.1  50.2  20.6   18.0
# 4   43.0  35.0  77.0   7.6  3.44   9.6  84.6  6441  24.4  43.7  14.3   43.0
# 5   53.0  45.0  80.0   7.7  3.45  10.2  66.8  3325  38.5  43.1  25.5   30.0
# 6   43.0  30.0  74.0  10.9  3.23  12.1  83.9  4679   3.5  49.2  11.3   21.0
# 7   45.0  30.0  73.0   9.3  3.29  10.6  86.0  2140   5.3  40.4  10.5    6.0
# 8   36.0  24.0  70.0   9.0  3.31  10.5  83.2  6582   8.1  42.5  12.6   18.0
# 9   36.0  27.0  72.0   9.5  3.36  10.7  79.3  4213   6.7  41.0  13.2   12.0
# 10  52.0  42.0  79.0   7.7  3.39   9.6  69.2  2302  22.2  41.3  24.2   18.0
# ...

# %%
df.to_numpy().shape
# Out:
# (60, 16)

# %%
data =  np.genfromtxt("Zadanie_1.csv", delimiter=';')
data
# Out:
# array([[         nan,          nan,          nan,          nan,
#                  nan,          nan,          nan,          nan,
#                  nan,          nan,          nan,          nan,
#                  nan,          nan,          nan,          nan],
#        [3.600000e+01, 2.700000e+01, 7.100000e+01, 8.100000e+00,
#         3.340000e+00, 1.140000e+01, 8.150000e+01, 3.243000e+03,
#         8.800000e+00, 4.260000e+01, 1.170000e+01, 2.100000e+01,
#                  nan, 5.900000e+01, 5.900000e+01, 9.218700e+02],
#        [3.500000e+01, 2.300000e+01, 7.200000e+01, 1.110000e+01,
#         3.140000e+00, 1.100000e+01, 7.880000e+01, 4.281000e+03,
#         3.600000e+00, 5.070000e+01, 1.440000e+01, 8.000000e+00,
#         1.000000e+01, 3.900000e+01, 5.700000e+01, 9.978750e+02],
#        [4.400000e+01, 2.900000e+01, 7.400000e+01, 1.040000e+01,
#         3.210000e+00, 9.800000e+00, 8.160000e+01, 4.260000e+03,
#         8.000000e-01, 3.940000e+01,          nan, 6.000000e+00,
# ...

# %%
#Zadanie 1
np.count_nonzero(data)
# Out:
# 976

# %%
#Zadanie 1b
np.shape(data)
# Out:
# (61, 16)

# %%
#Zadanie 1c
np.mean(data)
# Out:
# nan

# %%
np.std(data)
# Out:
# nan

# %%
np.var(data)
# Out:
# nan

# %%
data_without_nan2 =  np.genfromtxt("Zadanie_1.csv", delimiter=';', skip_header=1)
np.shape(data_without_nan2)
# Out:
# (60, 16)

# %%
data_without_nan = data[~np.isnan(data)]

data_without_nan
# Out:
# array([3.600000e+01, 2.700000e+01, 7.100000e+01, 8.100000e+00,
#        3.340000e+00, 1.140000e+01, 8.150000e+01, 3.243000e+03,
#        8.800000e+00, 4.260000e+01, 1.170000e+01, 2.100000e+01,
#        5.900000e+01, 5.900000e+01, 9.218700e+02, 3.500000e+01,
#        2.300000e+01, 7.200000e+01, 1.110000e+01, 3.140000e+00,
#        1.100000e+01, 7.880000e+01, 4.281000e+03, 3.600000e+00,
#        5.070000e+01, 1.440000e+01, 8.000000e+00, 1.000000e+01,
#        3.900000e+01, 5.700000e+01, 9.978750e+02, 4.400000e+01,
#        2.900000e+01, 7.400000e+01, 1.040000e+01, 3.210000e+00,
#        9.800000e+00, 8.160000e+01, 4.260000e+03, 8.000000e-01,
#        3.940000e+01, 6.000000e+00, 6.000000e+00, 3.300000e+01,
#        5.400000e+01, 9.623540e+02, 4.700000e+01, 4.500000e+01,
#        7.900000e+01, 6.500000e+00, 3.410000e+00, 1.110000e+01,
#        7.750000e+01, 3.125000e+03, 2.710000e+01, 5.020000e+01,
#        2.060000e+01, 1.800000e+01, 8.000000e+00, 2.400000e+01,
# ...

# %%
np.shape(data_without_nan)
np.isnan(data)
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False,  True, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False,  True, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
# ...

# %%
#Zadanie 1d
np.nanmean(data)
# Out:
# 338.2209319148936

# %%
np.nanstd(data)
# Out:
# 1018.0734716093722

# %%
np.nanvar(data)
# Out:
# 1036473.5935947591
